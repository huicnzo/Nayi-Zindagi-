# %% [markdown]
# Neural networks are not actually round-round
#
# In a dataset we have feature & label column .
# ![14.JPG](attachment:14.JPG)
#
#
# I have to build a model so that it will be able to understand a pattern in between a features & labels .
#
#
# in case of supervise learning there is two types regression & classification
# regression - we have to build a relation & give reslut in the form of real no. .. like what is temp?
#
# classification - in this case we will just classify data set into whether its hot/cold
#
# When we talk  about a ml model , everywhere it tries to train some kind of parameter .. in logistic regression log(p/1-p) = mx + c
#
# naiye byes -- p(a/b) = {P(b/a)* p(b)}/ P(a)
#
# ...but how a Neural network learns ...
#
# what happens inside it?
#
# In every part of our body there are neurons .
# it try to send data to brain , then with the help of past experience it will make decisions .
#
#
# # how ANN learn?
#
# this is not how exactly a neuron look like but we will assume this round structure .
#
# here objective is to learn whether it belong to label 1 or 2
#
# what a hidden layer des ?
#  this layer is responsible for learning , it could be possible that there is some relation between different features .multiple kind of permutations & combinations are possible for hidden layers & input layer connection ,
#
#  whenever you try to send a data from input to hidden layer , the input which will go to the hidden layer will be (2w1 + b)
#
#  input * weight + biases ... some what same as mx + c
#
#  every connection has a weight associated to it .
#
#  every hidden neuron has a bias associated to it .
#
#  ![15.JPG](attachment:15.JPG)

# %% [markdown]
# we can design nn without using any tf or keras libray but by using simple python ...
#
# # activation function
# inside a hidden layer there is something called as activation function ....
# what are its roles ?
#
# there are many activation function(50-60)
#
#
# Meaning & Significance of ACTIVATION FUNCTION
#
# 1) Sigmoid Activation FUnction -
#
# ![16.JPG](attachment:16.JPG)

# %% [markdown]
# it will give us value in between  0 to 1 always .
#
# there are others as well ... ReLu , maxout activation function
#
# # Activation function is been used to achieve a non-linearization into a dataset .
#
# in statistics we learnt about normalization ... it was like trying to bring a huge range of dataset into a small range /scale .because if we try to learn in a smaller range we can learn it better .
#
# like between 10 , 1000 there is diff of 990
# but betwenn log10 & log1000 there is diff of 1 to 3 ie 3.
#
# we are not changing meaning of dataset but scale of dataset .

# %% [markdown]
# sigmoid just normalize the dataset between 0 to 1 .
#
# i am trying to send 2w1 + 2w2 + 2b in ( 1 / 1+ e^-x)
# it will give me an output from this hidden neuron let it be o1 ....
#
# w1 wiill define the relation between the neurons it is connecting .
#
#
# .....sigmoid function is  a probability function as well for one label over other  ....
#
#
# if i was expecting a diffrent label & it gave me diff there must be some problem .. in the form of loss .
#
# losses are |actual y - predicted y| ... there are many types of loss .we will study cost function & optimisers & gradient descent
#
#
#
# # optimizing a loss
#
# actual - predicted = loss
# ....till now we are trying to move forward ..so it was a  forward connection .
#
# how i be able to decrease a loss?
# by adjusting the weights .
#
# In a forward propagation just passing a data with random weights ...
# now I want to find new value of weight & the biases .
#
#
# i will pass the data in optimizers ...( from backward propagation )
#
#
# ....i.e wrt to error trying to find new weights & biases .
#
#
# learning does not happen in forward it happens in backward propagation .
#
# in backward new value of weights will be given by de/dw11 de/dw10 de/dw12
#
# i will send data multiple times uless untill i will get a minimumm loss .
