# %% [markdown]
# inside this neural network so we
#
# were talking about a different different
#
# kind of a function like a sigmoid
#
# function or we talked about a loss
#
# function all we talked about optimizing
#
# in today's
#
# class I will be talking about first of
# all end to end activation function
#
# then I will
#
# be talking about a loss function and
#
# then I will be talking about a optimizer
#
# because the reason behind this
#
# discussion is so doesn't matter what
#
# these things you
#
# are going to use again and again in
#
# every neural network

# %% [markdown]
# # Activation Function
#
# whenever we are going to pass a data
#
# inside a neural network so in a hidden
#
# layer you are going to encounter an
#
# activation function
#
# inside this hidden
#
# neuron so we can try to use n number of
#
# activation function

# %% [markdown]
# # why we need an activation function ?
#
# activation function is been used to
#
# achieve a normalization that is true
#
# activation function has been used to
#
# achieve a non linearization into a input
#
# data that is also true an activation
#
# function is
#
# been used to achieve a generalization
#
# that is also true

# %% [markdown]
# # normalization
#
# let's suppose I have some
#
# data and trying to insert some of the
#
# data and some of the data is having a
#
# range in between one to hundred some
#
# other data is having a range in between
#
# hundred to two thousand or maybe some of
#
# the data is having a range in between
#
# one to 50,000 so or five lakh doesn't
#
# matter at all so suppose we are trying
#
# to insert a data and then my data is
#
# having a different different kind of
#
# ranges in which it has been dispersed or
#
# it has been distributed so for sure that
#
# is a huge dispersion that you will be
#
# able to find out in between a data set
#
# and if there is a huge dispersion that
#
# you are going to find out in between a
#
# data set so whenever I will try to send
#
# all of those data inside my network so
#
# it will be very difficult for my network
#
# to learn all of those data and  for finding
#
# out the patterns so it
#
# will be very difficult for my data set
#
# so we need some kind of a function or we
#
# need to do something by which I will be
#
# able to normalize it normalize it means
#
# so I will be able to bring down my data
#
# in between a certain range so all of my
#
# data should come in between certain
#
# range and in this way it will be easier
#
# for me to understand or to find out a
#
# relationship between the data set that
#
# is true
#
# ***every activation
# function try to give you some kind of
# output in between a boundaries***

# %% [markdown]
# **whenever we are
# going to do even a backward propagation
# so there will be a contribution of
# activation function we are going to take
# so we are going to find out a derivative
# or activation function and by doing that
# so we are going to calculate a new bits
# and a new biases **

# %% [markdown]
# ***normalization and strategy is a
# different terms and it's been used into
# a different perspective so both are not
# same***

# %% [markdown]
# # sigmoid function (oldest activation function)
#
# partially I can say that this is a probability function ,
#
#
# ***`disadvantage`***
# 1) for extreme negative data so
#    it is going to give you a data close to
#    0 and for extreme positive it is going
#    to give you a data close to like a I
#    would say 1
#
#    it is not going to return any value
#    below 0 or above 1 you're not going to get any
#    kind of a value which is symmetric
#    across a origin you are always going to
#    get a positive value ..you are not going to get zero centric value.
#
# 2) it is prone to a gradient
#    vanishing problem
#
#    - suppose if my value of x is too high or
#      if my value of x is too low if my input
#      is too high or too low means if it is
#      too negative or if it is too positive
#      so if I am trying to take a bigger
#      value so for sure it is not going to
#      give you any kind of a changes or any
#      kind of a variations on any of this axis(y-axis)
#
#    - if you will progress
#      from a backward direction from your last
#      layer till your first layer so you will
#      be able to find out
#      it is going to show you a vanishing gradient problem
#      means if you will keep on finding a derivative
#      means if you will progress
#      from a backward direction from your last
#      layer till your first layer so you will
#      be able to find out
#      whatever changes it is going to
#      do so that change will not be a
#      significant change that is called as a
#      vanishing gradient problem
#
#
#
#
# 3)  I am trying to
#     do a mathematical calculation in terms
#     of an exponential operation consume a lots and lots of computation
#     power.
#
#
# ***`applying sigmoid in output layer`***
# if I am going to use this
#
# function the sigmoid function on an
#
# output layer  and suppose if I am talking about
#
# a binary class classification(0/1) in that case I
#
# will be able to use this sigmoid
#
# function so this sigmoid function can
#
# comes as a handy because what happens is
#
# so it is going to give you  0, 1 & anything in between 0 & 1  and then you can
#
# try to apply your THRESHHOLD so that
#
# okay so lesser than this will be one
#
# class and greater than this will be
#
# another class this is how you will be
#
# able to apply a THRESHHOLD in that case you
#
# can say that ***it is behaving like a
# probability function but it's not a
# probability function .***

# %% [markdown]
# ***`advantage of sigmoid function`***
#
#
# 1)  whenever we have to converge means
#     whenever we are trying to fall into a
#     minima so yes it is going to give you a
#     smooth value it is not going to give you
#     a jump at any point of a time
#
#
# 2) it is one of
#    the best normalization function
#
# 3) it will be able
#    to give you a very clear prediction
#    because it will always try to give you
#    value very close to 1 or 0
#
#     ***so for a clear prediction or for clear classification I would say that even I can use a sigmoid function on a outer layer***

# %% [markdown]
# ![18.JPG](attachment:18.JPG)

# %% [markdown]
# # tan h function
#
# - zero centric
#
# - can used for the normalization
#
# - derivative of this function is
#   almost same as sigmoid function
#
# - even sigmoid function was
#   trying to give you a smooth curve and
#   even this tan h function is trying to
#   give me a smooth curve so in this term
#   both functions are same
#
# - in a for propagation it will try to
#   normalize a data and whatever data input
#   that you are going to give so it is
#   going to give you an output in between
#   minus 1 to plus 1
#   but if I'll talk about a backward
#   propagation so yes it is also going to
#   give me a continuous data so again it is
#   not going to give me a jump
#
# - you
#   can't consider this function as a
#   probability function
#
# - if you will try to derive again
#   and again and again after some
#   derivation so it is going to give you a
#   flat kind of a curve means after some
#   time you will be able to observe that
#   it is not able to change itself that is called as a
#   vanishing gradient .
#
# - both sigmoid & tanh functions does exponential computation
#
# -
#
#
#
# ![19.JPG](attachment:19.JPG)

# %% [markdown]
# # ReLu  - Rectified linear unit function
#
# I might
#
# end up losing a lot of information
#
# because I'm trying to like a compress a
#
# data set in between a very small range
#
# in above two functions
#
# this is linear function unlike above two functions

# %% [markdown]
# # Leaky ReLu Function
# here it is trying to remove some of the disadvantages of ReLu function
#
# Disadvantages of Relu function -
# - Relu was going to give me zero for all the negative values
#   but Leaky Relu is not going to give me zero for all the negative value
#
# - Relu was not a zero centric function , tho Leaky Relu is also not zero centric but it is going to give me some partial result
#   for a negative axis
#
# `computatinal expensiveness of relu & leaky relu is same`

# %% [markdown]
# # exponential linear unit function ELU
#
# ![20.JPG](attachment:20.JPG)
#
#
# `incomplete`

# %% [markdown]
# # softmax function
#
# ![21.JPG](attachment:21.JPG)
#
#  in case of a
#
# multi-class classification so this
#
# softness function has been used to find
#
# out a different different of probability
#
# of the different classes
#
# if I have taken a data [2,4,8,1]
#
# so what is a probability of
#
# occurrence of 8 or what is a probability
#
# of occurrence of 4 or what is a
#
# probability of occurrence of 2 or what
#
# is the probability of occurrence of 1
#
#  I wanted to
#
# consider a factor of a magnitude as well
#
# it is not
#
# trying to consider a number of
#
# occurrences so in that
#
# case how I will be able to find out a
#
# probability
#
#
# if you are going
#
# to get 6 they will be able
#
# to get more advantage as compared to
#
# those who will be able to get 4 or 1 in
#
# through our dials so in that case if you
#
# have to find out the probability where
#
# you are supposed to consider a magnitude
#
# so this is the function
#
# which we generally use in case of a
#
# multi-class classification remember that
#
# because we are going to use it many
#
# times on an outer layer so whenever we
#
# are going to design a network so in this
#
# outer layer because here we have to do a
#
# classification here we have to do a
#
# multi-class classification for every
#
# data that we are going to get
#
# one more observation
#
# more the numerical value
#
# it will be able to get
#
# a high stability for that
#
# whenever we are trying to do a
#
# classification so we always try to look
#
# for the probability and based on the
#
# probability so we try to give classes so
#
# for sure you are supposed to find out a
#
# probability
#
# value so you
#
# can't take any kind of a random number
#
# doesn't matter how high this number is
#
# and that's a region so you are going to
#
# get or you are going to take a sigmoid
#
# function and then the help of my buyer
#
# softmax function and with the help of
#
# softest function so you will try to find
#
# out a probability so that's the region
#
# so we are talking about a swatters
#
# function shortness function is also
#
# called as a activation function like I
#
# told you activation function is having a
#
# variety of the meaning somewhere Sothis
#
# function has been used for the
#
# normalization somewhere for like doing a
#
# normalization and somewhere it has been
#
# used for the realization

# %% [markdown]
# # PReLu  Parametric Relu
#
# Above ReLu function that we studied is been derived from this particular function
# ![22.JPG](attachment:22.JPG)
#
# every
#
# advantage every disadvantages
#
# that we discussed for above Relu functions are applicable for the PRelu funtion .
#
# `incomplete`

# %% [markdown]
# # Swish function
#  `incomplete`

# %% [markdown]
# # Loss
# many people generally gets confused
#
# between a loss or error or cost all
#
# these three things is same
#
#
#
# ***whenever we are going to
# calculate error just based on the single
# pass or just based on the single data
# that is called as a loss whenever we
# will try to calculate a error based on
# the combined or multiple inputs so
# combined error or combined loss if we
# are going to calculate that is called as
# a cost***

# %% [markdown]
# ![23.JPG](attachment:23.JPG)

# %% [markdown]
# the difference between l1 & l2 loss is that l2 loss is square loss so for a smaall diff it is going to give me really  small cost for a big diff it is going to give me really big cost which is disadvantage ... but yaa in case of small diff we should prefer l2 loss .

# %% [markdown]
# **Huber loss**
# it is actually combinatin of l1 & l2 loss in an attempt to try to make the combination better ...depending on the value of delta .
#
# what is delta here?
#
#
# ![24.JPG](attachment:24.JPG)
