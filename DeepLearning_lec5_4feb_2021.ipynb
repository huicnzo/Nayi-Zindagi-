# %% [markdown]
#  none of the activation function is a
#
# bad one it  depends upon the data set and
#
# depends upon the scenario
#
#  what kind of activation
#
# function we are going to
#
# use
#
# we can try
#
# to use a combination of
#
# multiple activation functions as well so
#
# it's not necessary that
#
# you are supposed to use only a single
#
# activation function
#
# into a various different different kind
#
# of layers

# %% [markdown]
# ![25.JPG](attachment:25.JPG)

# %% [markdown]
# # batch gradient descent
#
#  i
#
# have a data set
#
# so this is a table data which has been
#
# given to me
#
# it could be an image data it could be a
#
# like a signal data or it  could be a
#
# textual information or it could be a
#
# tabular information it doesn't matter at
#
# all so
#
# meaning of background decent is not
#
# going to change at all
#
#
#
#
#
#
# I have table column representing features rows reprsenting each set of data(each row representing each record)
#
# in case of a BGD i'll try to pass a entire data
# then it will take summation of loss for entire dataset then it is going to back-propagate & find out weight & biases .
#
# once we will get the whole loss we may try to do the optimization & we will try to find new coordinate of weight & biases .
#
# **disadvantage**
# it won't learn anything online .. online learning means giving single data everytime it will require whole data .
# so we won't be using this in case of online learning ..
#
# `code for bgd`
#
# ![26.JPG](attachment:26.JPG)

# %% [markdown]
# here para is some parameter .

# %% [markdown]
# but we are not going to use all this procedure  we are going to use the tensor flow library .

# %% [markdown]
# a gradient decent or the changes into
#
# our weight
#
# depends upon the volume of the data that
#
# we are going to send inside our
#
# entire network

# %% [markdown]
# bgd - it always guarantees
#
# that it will be able to converge to a
#
# global minima
#
# for the convex surface i would say and
#
# it will be able to like a converge to a
#
# local minima
#
# or a non convex kind of a surface

# %% [markdown]
# converge means to limit in between a particular range

# %% [markdown]
# # schotastic gradient descent
# if we are going to take some amount of
#
# data and based on that amount of
#
# data it will keep on changing a weight
#
# if we are going to
#
# take a sort of a data or maybe a bunch
#
# of the data
#
# and then if we are going to like uh
#
# train
#
# i will not going i will not face a
#
# memory kind of
#
# issue a mom issue that generally that we
#
# face
#
# in terms of training
#
# so maybe i will be
#
# able to handle those
#
# issues because here i'm not sending the
#
# entire data so i don't need a space or i
#
# don't need a main memory where i'm
#
# supposed to
#
# like keep the entire data set so maybe i
#
# just need a lesser memory
#
# over here
#
#
# # in case of sgd
#
# **1**] i will be sending
#
# batch
#
# one batch two batch three this is how i
#
# will be able to divide
#
# so for batch one i will try to send the
#
# entire data into the neural network for
#
# batch one i will try to send a data
#
# entire data into a neural network and
#
# then i will try to perform a
#
# backward propagation so in a backword
#
# propagation i will try to calculate a
#
# new value of weight and the biases
#
# possible

# %% [markdown]
#  **2** ] based on the change weight
#
# so again i will try to send on
#
# batch 2 and then again i will try to
#
# calculate a error i would say
#
# for a batch and then again i will try to
#
# find out a
#
# new like uh coordinates for weight and
#
# the
#
# biases so if we are going to perform
#
# this kind of a thing  this approach is called **schotastic gradient descent**

# %% [markdown]
# **3**] if we are going to take a
#
# data set in between 256 to 10 000
#
# we will go with sgd approach

# %% [markdown]
# curve for bgd & sgd would be diff coz in case of sgd we are going to pass data batch wise & in bgd we pass all the data at once .

# %% [markdown]
# `pseudo code for sgd`
# ![27.JPG](attachment:27.JPG)

# %% [markdown]
# we are trying to
#
# shuffle
#
# a data again and again
#
# this time i am trying to take a subset
#
# of the data and then based on that i am
#
# trying to perform the
#
# evaluation unlike in bgd

# %% [markdown]
# ***so in case of sgd it it is going to take smaller subset  of data & based on that smaller subset of data it will try t calculate  a weight and the biases it will be able calculate a local minima for that subset of thedata and then again so for the next set of the data it will try to maybe find out a new minima ,,you will be able to get a multiple minima so you will not be able to get an exact minima and then you have to find out the optimized one and again it will be a difficult task because  whenever i will try to find out that okay which one is better whether this one is better minima or this one is better minima or may be this one is a better minima so it will be hectic for me to decide that okay so which one is a better minima which one has converged into a proper way***

# %% [markdown]
# # Mini Badge Gradiet descent

# %% [markdown]
# if batch size is 50 to 256
#
# in between means by size means one sub
#
# sample of the data

# %% [markdown]
# mgd always try to give me a very good convergence , which simply means how easily it is going to give me weight & biases with very less balance .

# %% [markdown]
# cons of mgd -
# - learning rate
# -![28.JPG](attachment:28.JPG)

# %% [markdown]
# acc to google tensor board learning rate should be  10-0.00001 but it totallly dpends on me whta i ma going to take my learning rate as likee on the basis of experiments i have done ...
#
# 1) if we take learning rate too small it is going to give me a weight with not soo much ooff significant changes
#
# 2) if I take the learning rate too large it is going to oversuit the data .

# %% [markdown]
# for every we assumed the learning rate as constant for every epoch  but the learning process of our NN will improve with time a same learning rate would create some error .

# %% [markdown]
# cons of mgd -
# - here we were trying to calculate everything based on the previous one (n-1) but are we trying to consider the contributions of all the changes made in the past ? no ryt soo ..we are just considering a previous cases not all the changes that we made from the very beginning

# %% [markdown]
# till now whatever we studied in bgd , sgd & mgd was vanilla structure but in new structutre we only consider few % of n-1 not all of it ...nowadays we use momentum structure & not vanilla structure .

# %% [markdown]
# # optimizers
#
# # Adam optimizer
#
# Adaptive moment estimization
#
# if i am going to use adam in bgd sgd mgd it is possible i may try  to adapt a learning rate rather than fixing a learning rate
#
#
# mt - decaying averages of the past (delta w)
#
# vt - past squarredd gradient which means changes we have made in the past in gradient (delta e)
#
# gt - gradient
#
# ![29.JPG](attachment:29.JPG)

# %% [markdown]
# the denominator of vt cp + epsilon will keep on decreasing hence the overall learning rate factor will keep on increasing .
